# %% [markdown]
# **STUDENTS PERFORMANCE ANALYSING SYSTEM USING PYTHON,NUMPY AND PANDAS**

# %%
import numpy as np
import pandas as pd

# Load the dataset
df = pd.read_csv("students_performance_dataset_500.csv")
print("Dataset loaded successfully!")
print(df.shape)
# Out:
# Dataset loaded successfully!
# (500, 11)

# %% [markdown]
# **DATASET INSPECTION**

# %%
# Display first and last rows, shape, and columns
print(" First 5 rows ")
display(df.head())

print("\n Last 5 rows ")
display(df.tail())

print( df.shape)
print( df.columns)
# Out:
#  First 5 rows
#    Student_ID         Name  Age  Gender Department  Semester  Attendance  \
# 0        1001  Maryam Butt   18  Female         CS         3          56
# 1        1002   Hamza Shah   21  Female         CS         7          61
# 2        1003    Zain Butt   20  Female         AI         2          81
# 3        1004   John Akram   22  Female         CS         6          83
# 4        1005    Hina Shah   18  Female         IT         2          71
#
#    Assignment_Marks  Quiz_Marks  Mid_Marks  Final_Marks
# 0                16          15         15           30
# 1                 8          20         16           38
# 2                20          20         26           25
# 3                 9          17         14           26
# 4                12          14         28           46
#  Last 5 rows
#      Student_ID          Name  Age  Gender Department  Semester  Attendance  \
# 495        1496   Emma Sheikh   18  Female         DS         5          59
# 496        1497   Hassan Butt   18  Female         SE         3          69
# 497        1498  Sara Qureshi   22    Male         AI         7          81
# 498        1499   Zain Sheikh   24  Female         DS         8          58
# 499        1500     Sara Shah   21  Female         SE         1          99
#
#      Assignment_Marks  Quiz_Marks  Mid_Marks  Final_Marks
# 495                18          12         24           35
# 496                11           8         14           29
# 497                20           7         27           43
# 498                16          14         25           48
# 499                13           7         21           39
# (500, 11)
# Index(['Student_ID', 'Name', 'Age', 'Gender', 'Department', 'Semester',
#        'Attendance', 'Assignment_Marks', 'Quiz_Marks', 'Mid_Marks',
#        'Final_Marks'],
#       dtype='object')

# %% [markdown]
# ***EXPLORING DATASET SIZE***

# %%
total_students = len(df)
total_departments = df["Department"].nunique()
department_names = df["Department"].unique()
male_count = df[df["Gender"] == "Male"].shape[0]
female_count = df[df["Gender"] == "Female"].shape[0]

print(f"Total number of students: {total_students}")
print(f"Total unique departments: {total_departments}")
print(f"Department names: {department_names}")
print(f"Total male students: {male_count}")
print(f"Total female students: {female_count}")
# Out:
# Total number of students: 500
# Total unique departments: 5
# Department names: ['CS' 'AI' 'IT' 'SE' 'DS']
# Total male students: 241
# Total female students: 259

# %% [markdown]
# ***SELECTING COLUMNS***

# %%
# 11. Display only Name column
print("Name Column  ")
display(df["Name"])

# 12. Display Name, Department, and Final_Marks columns
print("\n Name, Department, and Final_Marks ")
display(df[["Name", "Department", "Final_Marks"]])

# 13. Display Name and Attendance columns
print("\n Name and Attendance ")
display(df[["Name", "Attendance"]].head())
# Out:
# Name Column
# 0       Maryam Butt
# 1        Hamza Shah
# 2         Zain Butt
# 3        John Akram
# 4         Hina Shah
#            ...
# 495     Emma Sheikh
# 496     Hassan Butt
# 497    Sara Qureshi
# 498     Zain Sheikh
# 499       Sara Shah
# Name: Name, Length: 500, dtype: object
#  Name, Department, and Final_Marks
#              Name Department  Final_Marks
# 0     Maryam Butt         CS           30
# 1      Hamza Shah         CS           38
# 2       Zain Butt         AI           25
# 3      John Akram         CS           26
# 4       Hina Shah         IT           46
# ..            ...        ...          ...
# 495   Emma Sheikh         DS           35
# 496   Hassan Butt         SE           29
# 497  Sara Qureshi         AI           43
# 498   Zain Sheikh         DS           48
# 499     Sara Shah         SE           39
#
# [500 rows x 3 columns]
#  Name and Attendance
#           Name  Attendance
# 0  Maryam Butt          56
# 1   Hamza Shah          61
# 2    Zain Butt          81
# 3   John Akram          83
# 4    Hina Shah          71

# %% [markdown]
# ***SELECTING ROWS***

# %%
#  First student using iloc
print(" First Student ")
display(df.iloc[0])

#  Fifth student using iloc
print("\nFifth Student")
display(df.iloc[4])

#  Last student using iloc
print("\n Last Student ")
display(df.iloc[-1])

# Student with index label 20 using loc
print("\n Student with index label 20 ")
display(df.loc[20])

# 18. Student with index label 100 using loc
print("\n Student with index label 100 ")
display(df.loc[100])
# Out:
#  First Student
# Student_ID                 1001
# Name                Maryam Butt
# Age                          18
# Gender                   Female
# Department                   CS
# Semester                      3
# Attendance                   56
# Assignment_Marks             16
# Quiz_Marks                   15
# Mid_Marks                    15
# Final_Marks                  30
# Name: 0, dtype: object
# Fifth Student
# Student_ID               1005
# Name                Hina Shah
# Age                        18
# Gender                 Female
# Department                 IT
# Semester                    2
# Attendance                 71
# Assignment_Marks           12
# Quiz_Marks                 14
# Mid_Marks                  28
# Final_Marks                46
# Name: 4, dtype: object
#  Last Student
# Student_ID               1500
# Name                Sara Shah
# Age                        21
# Gender                 Female
# Department                 SE
# Semester                    1
# Attendance                 99
# Assignment_Marks           13
# Quiz_Marks                  7
# Mid_Marks                  21
# Final_Marks                39
# Name: 499, dtype: object
#  Student with index label 20
# Student_ID               1021
# Name                Zain Butt
# Age                        23
# Gender                 Female
# Department                 SE
# Semester                    3
# Attendance                 78
# Assignment_Marks            9
# Quiz_Marks                 14
# Mid_Marks                  22
# Final_Marks                47
# Name: 20, dtype: object
#  Student with index label 100
# Student_ID                1101
# Name                Noor Ahmed
# Age                         20
# Gender                    Male
# Department                  DS
# Semester                     8
# Attendance                  73
# Assignment_Marks             9
# Quiz_Marks                  12
# Mid_Marks                   21
# Final_Marks                 27
# Name: 100, dtype: object

# %% [markdown]
# ***CONDITIONAL SELECTION***

# %%
# 19. Final Marks > 40
high_final = df[df["Final_Marks"] > 40]
print(f"Students with Final Marks > 40: {len(high_final)}")
#  Attendance > 90
high_attendance = df[df["Attendance"] > 90]
print(f"Students with Attendance > 90%: {len(high_attendance)}")
#  AI department students
ai_students = df[df["Department"] == "AI"]
print(f"Students from AI department: {len(ai_students)}")
#  CS department students
cs_students = df[df["Department"] == "CS"]
print(f"Students from CS department: {len(cs_students)}")
#  Age > 21
older_students = df[df["Age"] > 21]
print(f"Students with Age > 21: {len(older_students)}")
#  Quiz Marks > 15
high_quiz = df[df["Quiz_Marks"] > 15]
print(f"Students with Quiz Marks > 15: {len(high_quiz)}")
# Out:
# Students with Final Marks > 40: 169
# Students with Attendance > 90%: 104
# Students from AI department: 102
# Students from CS department: 111
# Students with Age > 21: 220
# Students with Quiz Marks > 15: 146

# %% [markdown]
# ***OPERATIONS OF NUMPY***

# %%
# Convert Final_Marks to a NumPy array
marks = df["Final_Marks"].to_numpy()
#  Maximum Final Marks
max_marks = np.max(marks)
print(f"Maximum Final Marks: {max_marks}")
#  Minimum Final Marks
min_marks = np.min(marks)
print(f"Minimum Final Marks: {min_marks}")
#  Average Final Marks
mean_marks = np.mean(marks)
print(f"Average Final Marks: {mean_marks:.2f}")
#  Square root of Final Marks
sqrt_marks = np.sqrt(marks)
print(f"Square root of Final Marks (First 5): {np.round(sqrt_marks[:5], 2)}")
#  Multiply every Final Mark by 2
double_marks = marks * 2
print(f"Final Marks multiplied by 2 (First 5): {double_marks[:5]}")
#  Convert Final Marks into float data type
float_marks = marks.astype(float)
print(f"Final Marks as float (Data type: {float_marks.dtype}, First 5): {float_marks[:5]}")
# Out:
# Maximum Final Marks: 50
# Minimum Final Marks: 20
# Average Final Marks: 35.08
# Square root of Final Marks (First 5): [5.48 6.16 5.   5.1  6.78]
# Final Marks multiplied by 2 (First 5): [60 76 50 52 92]
# Final Marks as float (Data type: float64, First 5): [30. 38. 25. 26. 46.]

# %% [markdown]
# ***FINAL PERFORMANCE REPORT***

# %%
# Compute report metrics
total_students_val = len(df)
total_departments_val = df["Department"].nunique()
avg_attendance_val = df["Attendance"].mean()
avg_final_marks_val = df["Final_Marks"].mean()
highest_final_marks_val = df["Final_Marks"].max()
lowest_final_marks_val = df["Final_Marks"].min()
# required summary format
print("=" * 50)
print("STUDENT PERFORMANCE REPORT")
print("=" * 50)
print(f"Total Students: {total_students_val}")
print(f"Total Departments: {total_departments_val}")
print(f"Average Attendance: {avg_attendance_val:.2f}%")
print(f"Average Final Marks: {avg_final_marks_val:.2f}")
print(f"Highest Final Marks: {highest_final_marks_val}")
print(f"Lowest Final Marks: {lowest_final_marks_val}")
print("=" * 50)
# Out:
# ==================================================
# STUDENT PERFORMANCE REPORT
# ==================================================
# Total Students: 500
# Total Departments: 5
# Average Attendance: 77.07%
# Average Final Marks: 35.08
# Highest Final Marks: 50
# Lowest Final Marks: 20
# ==================================================
